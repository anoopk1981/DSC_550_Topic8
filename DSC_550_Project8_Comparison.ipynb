# %%
# Models comparison

import numpy as np
import pandas as pd

N = [200, 1000, 5000]
D = 20
convRanges = [(0., 0.1), (0., 0.3), (0., 0.5)]

results = list()
for n in N:
    for ranges in convRanges:
        results.append([])
        for d  in range(3, D + 1):
            p1 = 0
            p2 = 0

            for rounds in range(1000):

                conversionRates = list()
                for i in range(d):
                    conversionRates.append(np.random.uniform(low = ranges[0], high = ranges[1]))

                X = np.zeros((n,d))
                for i in range(n):
                    for j in range(d):
                        if np.random.rand() < conversionRates[j]:
                            X[i][j] = 1

                nPosReward = np.zeros(d)
                nNegReward = np.zeros(d)

                for i in range(n):
                    selected = 0
                    maxRandom = 0

                    for j in range(d):
                        randomBeta = np.random.beta(nPosReward[j] + 1, nNegReward[j] + 1)
                        if randomBeta > maxRandom:
                            maxRandom = randomBeta
                            selected = j

                    if X[i][selected] == 1:
                        nPosReward[selected] += 1
                    else:
                        nNegReward[selected] += 1

                nSelected = nPosReward + nNegReward

                left = n - max(nSelected)

                countStandard = np.zeros(d)

                x = int(left / d)
                for i in range(x):
                    for j in range(d):
                        if X[i][j] == 1:
                            countStandard[j] += 1

                bestStandard = np.argmax(countStandard)
                bestReal = np.argmax(conversionRates)
                bestTS = np.argmax(nSelected)

                if bestTS == bestReal:
                    p1 += 1
                if bestStandard == bestReal:
                    p2 += 1

            print('N = ' + str(n) + ' d = ' + str(d) + ' range = ' + str(ranges) + ' | result Thompson Sampling = ' + str(p1) + ' result Standard solution = ' + str(p2))
            results.append([n, ranges, d, p1, p2])

df = pd.DataFrame(results)
df.to_excel('C:\\Users\\Anoops\\PycharmProjects\\pythonProject\\results.xlsx', sheet_name = 'Result', index = False)
# Out:
# N = 200 d = 3 range = (0.0, 0.1) | result Thompson Sampling = 673 result Standard solution = 569
# N = 200 d = 4 range = (0.0, 0.1) | result Thompson Sampling = 574 result Standard solution = 500
# N = 200 d = 5 range = (0.0, 0.1) | result Thompson Sampling = 483 result Standard solution = 426
# N = 200 d = 6 range = (0.0, 0.1) | result Thompson Sampling = 400 result Standard solution = 367
# N = 200 d = 7 range = (0.0, 0.1) | result Thompson Sampling = 358 result Standard solution = 339
# N = 200 d = 8 range = (0.0, 0.1) | result Thompson Sampling = 319 result Standard solution = 293
# N = 200 d = 9 range = (0.0, 0.1) | result Thompson Sampling = 292 result Standard solution = 280
# N = 200 d = 10 range = (0.0, 0.1) | result Thompson Sampling = 276 result Standard solution = 223
# N = 200 d = 11 range = (0.0, 0.1) | result Thompson Sampling = 248 result Standard solution = 246
# N = 200 d = 12 range = (0.0, 0.1) | result Thompson Sampling = 236 result Standard solution = 208
# N = 200 d = 13 range = (0.0, 0.1) | result Thompson Sampling = 216 result Standard solution = 206
# N = 200 d = 14 range = (0.0, 0.1) | result Thompson Sampling = 194 result Standard solution = 180
# N = 200 d = 15 range = (0.0, 0.1) | result Thompson Sampling = 182 result Standard solution = 175
# N = 200 d = 16 range = (0.0, 0.1) | result Thompson Sampling = 171 result Standard solution = 155
# N = 200 d = 17 range = (0.0, 0.1) | result Thompson Sampling = 155 result Standard solution = 152
# N = 200 d = 18 range = (0.0, 0.1) | result Thompson Sampling = 165 result Standard solution = 135
# N = 200 d = 19 range = (0.0, 0.1) | result Thompson Sampling = 147 result Standard solution = 123
# N = 200 d = 20 range = (0.0, 0.1) | result Thompson Sampling = 149 result Standard solution = 127
# N = 200 d = 3 range = (0.0, 0.3) | result Thompson Sampling = 777 result Standard solution = 671
# N = 200 d = 4 range = (0.0, 0.3) | result Thompson Sampling = 681 result Standard solution = 601
# N = 200 d = 5 range = (0.0, 0.3) | result Thompson Sampling = 606 result Standard solution = 501
# N = 200 d = 6 range = (0.0, 0.3) | result Thompson Sampling = 548 result Standard solution = 463
# N = 200 d = 7 range = (0.0, 0.3) | result Thompson Sampling = 528 result Standard solution = 446
# N = 200 d = 8 range = (0.0, 0.3) | result Thompson Sampling = 490 result Standard solution = 372
# N = 200 d = 9 range = (0.0, 0.3) | result Thompson Sampling = 444 result Standard solution = 327
# N = 200 d = 10 range = (0.0, 0.3) | result Thompson Sampling = 384 result Standard solution = 299
# N = 200 d = 11 range = (0.0, 0.3) | result Thompson Sampling = 363 result Standard solution = 310
# N = 200 d = 12 range = (0.0, 0.3) | result Thompson Sampling = 332 result Standard solution = 291
# N = 200 d = 13 range = (0.0, 0.3) | result Thompson Sampling = 304 result Standard solution = 256
# N = 200 d = 14 range = (0.0, 0.3) | result Thompson Sampling = 311 result Standard solution = 252
# N = 200 d = 15 range = (0.0, 0.3) | result Thompson Sampling = 270 result Standard solution = 199
# N = 200 d = 16 range = (0.0, 0.3) | result Thompson Sampling = 280 result Standard solution = 215
# N = 200 d = 17 range = (0.0, 0.3) | result Thompson Sampling = 244 result Standard solution = 193
# N = 200 d = 18 range = (0.0, 0.3) | result Thompson Sampling = 221 result Standard solution = 194
# N = 200 d = 19 range = (0.0, 0.3) | result Thompson Sampling = 226 result Standard solution = 173
# N = 200 d = 20 range = (0.0, 0.3) | result Thompson Sampling = 240 result Standard solution = 149
# N = 200 d = 3 range = (0.0, 0.5) | result Thompson Sampling = 817 result Standard solution = 713
# N = 200 d = 4 range = (0.0, 0.5) | result Thompson Sampling = 760 result Standard solution = 650
# N = 200 d = 5 range = (0.0, 0.5) | result Thompson Sampling = 700 result Standard solution = 559
# N = 200 d = 6 range = (0.0, 0.5) | result Thompson Sampling = 655 result Standard solution = 561
# N = 200 d = 7 range = (0.0, 0.5) | result Thompson Sampling = 620 result Standard solution = 491
# N = 200 d = 8 range = (0.0, 0.5) | result Thompson Sampling = 561 result Standard solution = 438
# N = 200 d = 9 range = (0.0, 0.5) | result Thompson Sampling = 524 result Standard solution = 387
# N = 200 d = 10 range = (0.0, 0.5) | result Thompson Sampling = 495 result Standard solution = 397
# N = 200 d = 11 range = (0.0, 0.5) | result Thompson Sampling = 482 result Standard solution = 380
# N = 200 d = 12 range = (0.0, 0.5) | result Thompson Sampling = 466 result Standard solution = 329
# N = 200 d = 13 range = (0.0, 0.5) | result Thompson Sampling = 435 result Standard solution = 357
# N = 200 d = 14 range = (0.0, 0.5) | result Thompson Sampling = 393 result Standard solution = 300
# N = 200 d = 15 range = (0.0, 0.5) | result Thompson Sampling = 400 result Standard solution = 283
# N = 200 d = 16 range = (0.0, 0.5) | result Thompson Sampling = 355 result Standard solution = 268
# N = 200 d = 17 range = (0.0, 0.5) | result Thompson Sampling = 335 result Standard solution = 256
# N = 200 d = 18 range = (0.0, 0.5) | result Thompson Sampling = 324 result Standard solution = 232
# N = 200 d = 19 range = (0.0, 0.5) | result Thompson Sampling = 291 result Standard solution = 221
# N = 200 d = 20 range = (0.0, 0.5) | result Thompson Sampling = 300 result Standard solution = 223
# N = 1000 d = 3 range = (0.0, 0.1) | result Thompson Sampling = 798 result Standard solution = 717
# N = 1000 d = 4 range = (0.0, 0.1) | result Thompson Sampling = 739 result Standard solution = 604
# N = 1000 d = 5 range = (0.0, 0.1) | result Thompson Sampling = 649 result Standard solution = 555
# N = 1000 d = 6 range = (0.0, 0.1) | result Thompson Sampling = 587 result Standard solution = 498
# N = 1000 d = 7 range = (0.0, 0.1) | result Thompson Sampling = 580 result Standard solution = 452
# N = 1000 d = 8 range = (0.0, 0.1) | result Thompson Sampling = 523 result Standard solution = 410
# N = 1000 d = 9 range = (0.0, 0.1) | result Thompson Sampling = 476 result Standard solution = 385
# N = 1000 d = 10 range = (0.0, 0.1) | result Thompson Sampling = 444 result Standard solution = 361
# N = 1000 d = 11 range = (0.0, 0.1) | result Thompson Sampling = 406 result Standard solution = 340
# N = 1000 d = 12 range = (0.0, 0.1) | result Thompson Sampling = 381 result Standard solution = 324
# N = 1000 d = 13 range = (0.0, 0.1) | result Thompson Sampling = 362 result Standard solution = 303
# N = 1000 d = 14 range = (0.0, 0.1) | result Thompson Sampling = 328 result Standard solution = 273
# N = 1000 d = 15 range = (0.0, 0.1) | result Thompson Sampling = 328 result Standard solution = 280
# N = 1000 d = 16 range = (0.0, 0.1) | result Thompson Sampling = 322 result Standard solution = 244
# N = 1000 d = 17 range = (0.0, 0.1) | result Thompson Sampling = 292 result Standard solution = 256
# N = 1000 d = 18 range = (0.0, 0.1) | result Thompson Sampling = 264 result Standard solution = 231
# N = 1000 d = 19 range = (0.0, 0.1) | result Thompson Sampling = 268 result Standard solution = 198
# N = 1000 d = 20 range = (0.0, 0.1) | result Thompson Sampling = 249 result Standard solution = 210
# N = 1000 d = 3 range = (0.0, 0.3) | result Thompson Sampling = 894 result Standard solution = 758
# N = 1000 d = 4 range = (0.0, 0.3) | result Thompson Sampling = 827 result Standard solution = 720
# N = 1000 d = 5 range = (0.0, 0.3) | result Thompson Sampling = 795 result Standard solution = 632
# N = 1000 d = 6 range = (0.0, 0.3) | result Thompson Sampling = 747 result Standard solution = 593
# N = 1000 d = 7 range = (0.0, 0.3) | result Thompson Sampling = 703 result Standard solution = 569
# N = 1000 d = 8 range = (0.0, 0.3) | result Thompson Sampling = 669 result Standard solution = 520
# N = 1000 d = 9 range = (0.0, 0.3) | result Thompson Sampling = 652 result Standard solution = 490
# N = 1000 d = 10 range = (0.0, 0.3) | result Thompson Sampling = 617 result Standard solution = 474
# N = 1000 d = 11 range = (0.0, 0.3) | result Thompson Sampling = 566 result Standard solution = 427
# N = 1000 d = 12 range = (0.0, 0.3) | result Thompson Sampling = 547 result Standard solution = 423
# N = 1000 d = 13 range = (0.0, 0.3) | result Thompson Sampling = 557 result Standard solution = 383
# N = 1000 d = 14 range = (0.0, 0.3) | result Thompson Sampling = 495 result Standard solution = 350
# N = 1000 d = 15 range = (0.0, 0.3) | result Thompson Sampling = 487 result Standard solution = 360
# N = 1000 d = 16 range = (0.0, 0.3) | result Thompson Sampling = 466 result Standard solution = 315
# N = 1000 d = 17 range = (0.0, 0.3) | result Thompson Sampling = 434 result Standard solution = 341
# N = 1000 d = 18 range = (0.0, 0.3) | result Thompson Sampling = 457 result Standard solution = 312
# N = 1000 d = 19 range = (0.0, 0.3) | result Thompson Sampling = 410 result Standard solution = 278
# N = 1000 d = 20 range = (0.0, 0.3) | result Thompson Sampling = 392 result Standard solution = 277
# N = 1000 d = 3 range = (0.0, 0.5) | result Thompson Sampling = 916 result Standard solution = 792
# N = 1000 d = 4 range = (0.0, 0.5) | result Thompson Sampling = 862 result Standard solution = 719
# N = 1000 d = 5 range = (0.0, 0.5) | result Thompson Sampling = 848 result Standard solution = 721
# N = 1000 d = 6 range = (0.0, 0.5) | result Thompson Sampling = 826 result Standard solution = 642
# N = 1000 d = 7 range = (0.0, 0.5) | result Thompson Sampling = 783 result Standard solution = 592
# N = 1000 d = 8 range = (0.0, 0.5) | result Thompson Sampling = 743 result Standard solution = 590
# N = 1000 d = 9 range = (0.0, 0.5) | result Thompson Sampling = 717 result Standard solution = 532
# N = 1000 d = 10 range = (0.0, 0.5) | result Thompson Sampling = 693 result Standard solution = 528
# N = 1000 d = 11 range = (0.0, 0.5) | result Thompson Sampling = 685 result Standard solution = 474
# N = 1000 d = 12 range = (0.0, 0.5) | result Thompson Sampling = 673 result Standard solution = 458
# N = 1000 d = 13 range = (0.0, 0.5) | result Thompson Sampling = 614 result Standard solution = 449
# N = 1000 d = 14 range = (0.0, 0.5) | result Thompson Sampling = 637 result Standard solution = 404
# N = 1000 d = 15 range = (0.0, 0.5) | result Thompson Sampling = 580 result Standard solution = 421
# N = 1000 d = 16 range = (0.0, 0.5) | result Thompson Sampling = 550 result Standard solution = 393
# N = 1000 d = 17 range = (0.0, 0.5) | result Thompson Sampling = 549 result Standard solution = 394
# N = 1000 d = 18 range = (0.0, 0.5) | result Thompson Sampling = 533 result Standard solution = 353
# N = 1000 d = 19 range = (0.0, 0.5) | result Thompson Sampling = 516 result Standard solution = 361
# N = 1000 d = 20 range = (0.0, 0.5) | result Thompson Sampling = 508 result Standard solution = 334
# N = 5000 d = 3 range = (0.0, 0.1) | result Thompson Sampling = 885 result Standard solution = 771
# N = 5000 d = 4 range = (0.0, 0.1) | result Thompson Sampling = 849 result Standard solution = 710
# N = 5000 d = 5 range = (0.0, 0.1) | result Thompson Sampling = 814 result Standard solution = 675
# N = 5000 d = 6 range = (0.0, 0.1) | result Thompson Sampling = 749 result Standard solution = 619
# N = 5000 d = 7 range = (0.0, 0.1) | result Thompson Sampling = 736 result Standard solution = 591
# N = 5000 d = 8 range = (0.0, 0.1) | result Thompson Sampling = 696 result Standard solution = 572
# N = 5000 d = 9 range = (0.0, 0.1) | result Thompson Sampling = 678 result Standard solution = 513
# N = 5000 d = 10 range = (0.0, 0.1) | result Thompson Sampling = 648 result Standard solution = 499
# N = 5000 d = 11 range = (0.0, 0.1) | result Thompson Sampling = 634 result Standard solution = 463
# N = 5000 d = 12 range = (0.0, 0.1) | result Thompson Sampling = 578 result Standard solution = 431
# N = 5000 d = 13 range = (0.0, 0.1) | result Thompson Sampling = 587 result Standard solution = 448
# N = 5000 d = 14 range = (0.0, 0.1) | result Thompson Sampling = 539 result Standard solution = 376
# N = 5000 d = 15 range = (0.0, 0.1) | result Thompson Sampling = 531 result Standard solution = 393
# N = 5000 d = 16 range = (0.0, 0.1) | result Thompson Sampling = 505 result Standard solution = 364
# N = 5000 d = 17 range = (0.0, 0.1) | result Thompson Sampling = 471 result Standard solution = 365
# N = 5000 d = 18 range = (0.0, 0.1) | result Thompson Sampling = 495 result Standard solution = 323
# N = 5000 d = 19 range = (0.0, 0.1) | result Thompson Sampling = 457 result Standard solution = 296
# N = 5000 d = 20 range = (0.0, 0.1) | result Thompson Sampling = 426 result Standard solution = 308
# N = 5000 d = 3 range = (0.0, 0.3) | result Thompson Sampling = 938 result Standard solution = 822
# N = 5000 d = 4 range = (0.0, 0.3) | result Thompson Sampling = 896 result Standard solution = 769
# N = 5000 d = 5 range = (0.0, 0.3) | result Thompson Sampling = 879 result Standard solution = 702
# N = 5000 d = 6 range = (0.0, 0.3) | result Thompson Sampling = 870 result Standard solution = 682
# N = 5000 d = 7 range = (0.0, 0.3) | result Thompson Sampling = 841 result Standard solution = 660
# N = 5000 d = 8 range = (0.0, 0.3) | result Thompson Sampling = 866 result Standard solution = 624
# N = 5000 d = 9 range = (0.0, 0.3) | result Thompson Sampling = 799 result Standard solution = 605
# N = 5000 d = 10 range = (0.0, 0.3) | result Thompson Sampling = 776 result Standard solution = 573
# N = 5000 d = 11 range = (0.0, 0.3) | result Thompson Sampling = 771 result Standard solution = 585
# N = 5000 d = 12 range = (0.0, 0.3) | result Thompson Sampling = 735 result Standard solution = 501
# N = 5000 d = 13 range = (0.0, 0.3) | result Thompson Sampling = 728 result Standard solution = 519
# N = 5000 d = 14 range = (0.0, 0.3) | result Thompson Sampling = 743 result Standard solution = 473
# N = 5000 d = 15 range = (0.0, 0.3) | result Thompson Sampling = 690 result Standard solution = 478
# N = 5000 d = 16 range = (0.0, 0.3) | result Thompson Sampling = 709 result Standard solution = 444
# N = 5000 d = 17 range = (0.0, 0.3) | result Thompson Sampling = 644 result Standard solution = 461
# N = 5000 d = 18 range = (0.0, 0.3) | result Thompson Sampling = 663 result Standard solution = 437
# N = 5000 d = 19 range = (0.0, 0.3) | result Thompson Sampling = 623 result Standard solution = 408
# N = 5000 d = 20 range = (0.0, 0.3) | result Thompson Sampling = 613 result Standard solution = 396
# N = 5000 d = 3 range = (0.0, 0.5) | result Thompson Sampling = 954 result Standard solution = 858
# N = 5000 d = 4 range = (0.0, 0.5) | result Thompson Sampling = 943 result Standard solution = 802
# N = 5000 d = 5 range = (0.0, 0.5) | result Thompson Sampling = 926 result Standard solution = 769
# N = 5000 d = 6 range = (0.0, 0.5) | result Thompson Sampling = 901 result Standard solution = 748
# N = 5000 d = 7 range = (0.0, 0.5) | result Thompson Sampling = 913 result Standard solution = 697
# N = 5000 d = 8 range = (0.0, 0.5) | result Thompson Sampling = 879 result Standard solution = 652
# N = 5000 d = 9 range = (0.0, 0.5) | result Thompson Sampling = 876 result Standard solution = 639
# N = 5000 d = 10 range = (0.0, 0.5) | result Thompson Sampling = 822 result Standard solution = 605
# N = 5000 d = 11 range = (0.0, 0.5) | result Thompson Sampling = 842 result Standard solution = 582
# N = 5000 d = 12 range = (0.0, 0.5) | result Thompson Sampling = 841 result Standard solution = 577
# N = 5000 d = 13 range = (0.0, 0.5) | result Thompson Sampling = 813 result Standard solution = 533
# N = 5000 d = 14 range = (0.0, 0.5) | result Thompson Sampling = 798 result Standard solution = 550
# N = 5000 d = 15 range = (0.0, 0.5) | result Thompson Sampling = 799 result Standard solution = 539
# N = 5000 d = 16 range = (0.0, 0.5) | result Thompson Sampling = 772 result Standard solution = 535
# N = 5000 d = 17 range = (0.0, 0.5) | result Thompson Sampling = 756 result Standard solution = 493
# N = 5000 d = 18 range = (0.0, 0.5) | result Thompson Sampling = 767 result Standard solution = 488
# N = 5000 d = 19 range = (0.0, 0.5) | result Thompson Sampling = 738 result Standard solution = 437
# N = 5000 d = 20 range = (0.0, 0.5) | result Thompson Sampling = 732 result Standard solution = 449
